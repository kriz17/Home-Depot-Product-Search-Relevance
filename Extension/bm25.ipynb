# %%
# %cd /content/drive/MyDrive/Home_Depot_Case_Study/Workspace4
# Out:
# /content/drive/MyDrive/Home_Depot_Case_Study/Workspace4

# %%
import pandas as pd
import numpy as np
import regex as re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
attr_df = pd.read_csv("attributes.csv", encoding='iso-8859-1')
desc_df = pd.read_csv('product_descriptions.csv', encoding='iso-8859-1')
train_df = pd.read_csv("train.csv", encoding='iso-8859-1')
test_df = pd.read_csv('test.csv', encoding='iso-8859-1')

# %% [markdown]
# Merging

# %%
def merge_attributes(df):
  product_uids = df['product_uid'].values
  temp = attr_df.loc[attr_df['product_uid'].isin(product_uids)].fillna('')  
  temp['name_value'] = temp['name'] + ' ' + temp['value']
  temp['combined_attr'] = temp.groupby(['product_uid'])['name_value'].transform(lambda x: ' '.join(x))
  temp = temp.drop_duplicates('product_uid')[['product_uid', 'combined_attr']]
  df = pd.merge(df, temp, on='product_uid', how='left').set_index(df.index)
  return df

def merge_brand(df):
  product_uids = df['product_uid'].values
  temp = attr_df.loc[attr_df['product_uid'].isin(product_uids)]  
  brands = temp[temp['name']=='MFG Brand Name']
  brands_temp = brands[['product_uid','value']]
  df = pd.merge(df, brands_temp, on='product_uid', how='left').set_index(df.index)
  df.rename(columns = {'value':'brand'}, inplace = True) 
  return df

def merge_description(df):
  df = pd.merge(df, desc_df, on='product_uid', how='left').set_index(df.index)
  #an extra preprocessing step is performed to seperate the concatenated words in the description. 
  df['product_description'] = df['product_description'].apply(lambda x: ' '.join(re.findall(r'[A-Z]?[^A-Z\s]+|[A-Z]+', x)))
  return df

# %%
train_df = merge_attributes(train_df)
train_df = merge_brand(train_df)
train_df = merge_description(train_df)

test_df = merge_attributes(test_df)
test_df = merge_brand(test_df)
test_df = merge_description(test_df)

train_df = train_df.drop('relevance', axis=1)

combined_df = pd.concat([train_df, test_df], axis=0).reset_index()
combined_df = combined_df.drop_duplicates('product_uid')
print(combined_df.shape)
combined_df.isna().sum()
# Out:
# (124428, 8)
# index                      0
# id                         0
# product_uid                0
# product_title              0
# search_term                0
# combined_attr          38165
# brand                  38243
# product_description        0
# dtype: int64

# %% [markdown]
# Filling null values

# %%
def first_n(n, sent):
  if n > len(sent.split()):
    return 'error101'
  return ' '.join(sent.split()[:n])

def fillna_brand(data, unique_brnds):
  null_df = data[data['brand'].isnull()]
  notnull_df = data.dropna()

  for i, row in null_df.iterrows():
    title = row['product_title']
    if first_n(4, title) in unique_brnds:
      null_df['brand'].loc[i] = first_n(4, title)
    elif first_n(3, title) in unique_brnds:
      null_df['brand'].loc[i] = first_n(3, title)
    elif first_n(2, title) in unique_brnds:
      null_df['brand'].loc[i] = first_n(2, title)
    else:
      null_df['brand'].loc[i] = first_n(1, title)

  data['brand'].loc[null_df.index] = null_df['brand'].values
  return data

def fillna_attributes(data):
  null_df = data[data['combined_attr'].isnull()]
  null_df['combined_attr'] = null_df['product_description'].copy()
  data['combined_attr'].loc[null_df.index] = null_df['combined_attr'].values
  return data

unique_brands = list(combined_df['brand'].unique())
print(len(unique_brands))

combined_df = fillna_brand(combined_df, unique_brands)
combined_df = fillna_attributes(combined_df)

combined_df.isna().sum()
# Out:
# 4289
# index                  0
# id                     0
# product_uid            0
# product_title          0
# search_term            0
# combined_attr          0
# brand                  0
# product_description    0
# dtype: int64

# %% [markdown]
# creating the text field

# %%
combined_df['text'] = combined_df['product_title'] + ' ' + combined_df['brand'] + ' ' + combined_df['product_description']
temp = combined_df.drop(['index', 'id', 'search_term'], axis=1)
print(temp.shape)
temp.head()
# Out:
# (124428, 6)
#    product_uid  ...                                               text
# 0       100001  ...  Simpson Strong-Tie 12-Gauge Angle Simpson Stro...
# 2       100002  ...  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3       100005  ...  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5       100006  ...  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8       100007  ...  Lithonia Lighting Quantum 2-Light Black LED Em...
#
# [5 rows x 6 columns]

# %%
def standardize_units(text):
  text = " " + text + " "
  text = re.sub('( gal | gals | galon )',' gallon ',text)
  text = re.sub('( ft | fts | feets | foot | foots )',' feet ',text)
  text = re.sub('( squares | sq )',' square ',text)
  text = re.sub('( lb | lbs | pounds )',' pound ',text)
  text = re.sub('( oz | ozs | ounces | ounc )',' ounce ',text)
  text = re.sub('( yds | yd | yards )',' yard ',text)
  return text

def preprocessing(sent):
  sent = sent.replace('in.', ' inch ') #If we dont to this then 'in.' will be turned to 'in' in the next step
  words = re.split(r'\W+', sent)
  words = [word.lower() for word in words]
  res = re.sub("[A-Za-z]+", lambda ele: " " + ele[0] + " ", ' '.join(words)) #add space between number and alphabets in a string
  cleaned = standardize_units(res) 
  cleaned = ' '.join(cleaned.split()) #removing extra whitespaces
  return cleaned

temp['text'] = temp['text'].apply(lambda x : preprocessing(x))
temp.head()
# Out:
#    product_uid  ...                                               text
# 0       100001  ...  simpson strong tie 12 gauge angle simpson stro...
# 2       100002  ...  behr premium textured deckover 1 gallon sc 141...
# 3       100005  ...  delta vero 1 handle shower only faucet trim ki...
# 5       100006  ...  whirlpool 1 9 cu feet over the range convectio...
# 8       100007  ...  lithonia lighting quantum 2 light black led em...
#
# [5 rows x 6 columns]

# %% [markdown]
# creating database for correction of search

# %%
temp['cleaned_title'] = temp['product_title'].apply(lambda x : preprocessing(x))
temp['cleaned_brand'] = temp['brand'].apply(lambda x : preprocessing(x))
corpus = temp['cleaned_title'] + " "  + temp['cleaned_brand'] 

#removing stopwords
stp_wrds = set(stopwords.words('english'))
def stop_word_removal(sent):
  words = sent.split()
  words = [w for w in words if not w in stp_wrds]
  return ' '.join(words)

corpus = corpus.apply(lambda x : stop_word_removal(x)) 
np.savetxt(r'Final/cleaning/corpus.txt', corpus.values, fmt='%s')

# %% [markdown]
# testing the spelling corrector

# %%
#http://norvig.com/spell-correct.html
def words(text): return re.findall(r'\w+', text.lower())
WORDS = Counter(words(open('Final/cleaning/corpus.txt').read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N
def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)
def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or set([word]))
def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)
def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)
def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))
def corrected_term(term):
  temp = term.lower().split()
  temp = [correction(word) for word in temp]
  return ' '.join(temp)

# %%
for typo in [
             'air conditionar', 
             'toiled',
             'lawn mowe',
             'water heatwr'
]:
  print(corrected_term(typo))
# Out:
# air conditioner
# toilet
# lawn mower
# water heater

# %% [markdown]
# saving the file

# %%
temp.drop(['cleaned_title', 'cleaned_brand'], axis=1).to_csv('database.csv', index=False)

# %% [markdown]
# ### Rank BM25

# %%
# !pip install rank_bm25
# Out:
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rank_bm25) (1.19.5)

# %%
from rank_bm25 import BM25Okapi
corpus = temp['text'].values
tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
query = "lawn mower"
tokenized_query = query.split(" ")

bm25.get_top_n(tokenized_query, corpus, n=10)
# Out:
# ['lawn boy 4 5 ounce green paint spray can lawn boy touch up scratches on your lawn boy walk power mower with this lawn boy green touch up spray paint this spray paint can contains the official lawn boy pantone green color and can be used to touch up scuffs or scratches on your lawn boy mower the can contains 12 ounce and can be used time and time again to keep your lawn boy mower looking new 4 5 ounce can official lawn boy pantone green color use to touch up your lawn boy walk power mower keep your lawn boy looking new for many years',
#  'ego 20 inch mower blade ego use the ego 20 inch mower blade when you need a fresh sharp blade for your ego power plus lawn mower this replacement blade is designed for specifically the ego 20 inch mower give your lawn the best sharp cut for a crisp and attractive look 3 in 1 mower blade for mulching bagging and side discharging designed specifically for ego power plus mower model lm 2001 factory sharpened steel blade for excellent cutting performance delivers a clean cut to promote lawn health',
#  'homelite 20 inch electric replacement mower blade homelite to keep your lawn mower s high quality cut consider using the homelite 20 inch electric replacement mower blade for homelite brands this durable blade is easy to install into your homelite electric lawn mower the tempered carbon steel blade provides many season of precision cuts a new replacement blade will offer a manicured and well cut lawn assembled dimension 19 inch w x 2 inch d x 0 8 inch hf its models ut 13124 ut 13126 ut 13120 and ut 13122 durable easy installation for replacing homelite electric lawn mower blades',
#  'cub cadet 46 inch lawn tractor blade set for lawn tractors with 46 inch decks cub cadet replacing your cub cadet mower blades as part of your routine mower maintenance will allow your mower to keep performing it its peak performance a sharp set of mower blades helps to promote a healthy lawn by cutting each blade of grass cleanly using original equipment mower blades contributes to keeping the safety and quality of your machine fits cub cadet lawn tractors with 46 inch decks 2006 and after replaces oe parts 742 04124 742 04125 942 04124 and 942 041251 inch star center hole contains one set of 3 blades note product may vary by store',
#  'mojack hdl 500 lawn mower lift mojack the mo jack hdl 500 lawn mower lift lets you safely keep up with lawn mower maintenance like belt replacement blade sharpening and debris removal with a front load lift capacity of 500 pound and adjustable wheel pads this lift will accommodate most residential riding lawn tractors and ztr mowers the wheel pads expand to an outside wheel measurement of 50 inch the mo jack hdl 500 lifts your mower up to 24 inch high for easy and safe access to the mower undercarriage the lift also folds flat for space saving storage when not in use there is assembly required no assembly required front load capacity of 500 pound folds flat for easy storage adjustable wheel pads to fit almost any riding or ztr mower lifts mower safely up to 24 inch multi level safety braking system home depot protection plan',
#  'dremel sharpening kit dremel the dremel sharpening kit contains three attachments that let you maintain your outdoor garden tools with ease the lawn mower sharpener sharpens your lawn mower blades for a healthy beautiful lawn the garden tool sharpener sharpens garden tools such as shovels shears hoes and axes so they work more efficiently and the dremel chain saw sharpener lets you sharpen dull slow cutting chain saw blades instructions included lawn mower guide provides optimal sharpening angle for all lawn mower blades easily sharpen dull slow cutting chain saw blades easily screws on to your rotary tool in place of the tool s housing cap includes garden tool sharpening attachment lawn mower sharpening attachment chain saw sharpening attachment gauge spacers wrench and 4 sharpening stones 453 454 455 and 932 click here to connect to the world s most talented novice diy ers in one community share learn connect and inspire craft fix build join now',
#  'cub cadet 46 inch lawn tractor blade set for ltx 1045 riding lawn tractors 2009 and after cub cadet replacing your cub cadet mower blades as part of your routine mower maintenance will allow your mower to keep performing it its peak performance a sharp set of mower blades helps to promote a healthy lawn by cutting each blade of grass cleanly using original equipment mower blades contributes to keeping the safety and quality of your machine fit cub cadet series 1000 ltx lawn tractors 2009 and after replaces oe 742 04244 742 04244 a 942 04244 and 942 04244 a 2 in 1 design is suitable for discharging or bagging 1 inch star center hole includes 2 blades note product may vary by store',
#  'cub cadet 33 inch replacement walk behind mower blades 2 pack cub cadet replacing your cub cadet mower blades as part of your routine mower maintenance will allow your mower to keep performing it its peak performance a sharp set of mower blades helps to promote a healthy lawn by cutting each blade of grass cleanly using original equipment mower blades contributes to keeping the safety and quality of your machine replacement lawn mower blades designed to fit cub cadet 33 inch wide area walk behind mowers replaces oe 742 04154 star center hole pattern',
#  'black bull lawn mower tilt jack with hydraulic lift discontinued black bull this professional duty lawn mower tilt jack allows you to easily raise and manage your heavy equipment with a 660 pound raising capacity this tool becomes ideal for changing and servicing lawn mower blades or cleaning the undercarriage drive your riding lawn mower or tractor onto the tilt frame use the included hydraulic jack to raise the lawn mower up to a 45 degree angle assembled dimension 25 inch w x 52 inch d x 43 inch hm ax lifting range 0 45 degrees includes a steel brace and a separate brake lever for added safety set the safety lip place the brace for added stability support the hydraulic lift lowers the tractor back to ground level with control and ease folds to only 10 inch high so it is easy to store a useful tool for on the farm and at home perfect for home or the farm 660 pound capacity',
#  'cub cadet 42 inch lawn tractor blade set for ltx 1040 2009 timed decks cub cadet replacing your cub cadet mower blades as part of your routine mower maintenance will allow your mower to keep performing it its peak performance a sharp set of mower blades helps to promote a healthy lawn by cutting each blade of grass cleanly using original equipment mower blades contributes to keeping the safety and quality of your machine fits ltx 1042 lawn tractors with timed decks 2009 and after also fits i 1042 ztt timed decks 2008 contains one set of two blades 1 inch star center hole replaces oe parts 742 04217 and 942 04217 note product may vary by store']

# %%
query = "air conditioner"
tokenized_query = query.split(" ")

bm25.get_top_n(tokenized_query, corpus, n=10)
# Out:
# ['duck covers elite 34 inch round air conditioner cover duck covers duck covers air conditioner covers provide breakthrough protection that keep air conditioners protected when not in use our innovative multi layered material creates superior airflow between your air conditioner cover and air conditioner eliminating condensation that can damage your outdoor condenser duck covers do not crack or fade over time migrate to the best air conditioner cover today air conditioner cover is 34 inch dia x 30 inch h 100 waterproof air conditioner cover like water off a duck s back breathable uv treated material is used in all duck covers patio heater covers this material won t crack in cold weather easy to use lightweight material thats easy to fold and store 2 inch wide velcro straps to secure air conditioner cover in place',
#  'duck covers elite 34 inch square air conditioner cover duck covers duck covers air conditioner covers provide breakthrough protection that keep air conditioners protected when not in use our innovative multi layered material creates superior airflow between your air conditioner cover and air conditioner eliminating condensation that can damage your outdoor condenser duck covers do not crack or fade over time migrate to the best air conditioner cover today air conditioner cover is 34 inch w x 34 inch l x 30 inch h 100 waterproof air conditioner cover like water off a duck s back breathable uv treated material is used in all duck covers patio heater covers this material won t crack in cold weather easy to use lightweight material thats easy to fold and store 2 inch wide velcro straps to secure air conditioner cover in place',
#  'frost king e o 24 inch x 13 1 2 inch nylon air conditioner filter frost king this 24 inch x 13 1 2 inch nylon air conditioner filter helps filter pollen and dust from the air the filter is washable and reusable and can be cut to fit many sizes of window air conditioner replacement air conditioner filter replaces many sizes of window air conditioner filter helps save energy nylon construction helps filter out pollen and dust from the air washable reusable cut to fit',
#  'frost king e o 34 inch x 30 inch round central air conditioner cover frost king the thermwell products 34 inch x 30 inch round central air conditioner cover makes it easy to protect expensive air conditioner units from damage caused by winter weather the heavy duty polyethylene cover is waterproof and helps protect your air conditioner from rust the cover includes elasticized straps for a snug fit fits round central air conditioner units protects against rust to helps prolong the life of your air conditioner helps prevent cold air from entering the home during the winter heavy duty 6 mil polyethylene construction is waterproof and resists cracking and mildew reinforced corners elastic straps provide a secure fit durable and reusable',
#  'danby 12 000 btu portable air conditioner and dehumidifier with remote discontinued danby the danby s dpac 12010 h 3 in 1 portable air conditioner is an air conditioner dehumidifier and fan all in one compact unit this 12 000 btu air conditioner will cool an area up to 500 square feet it also serves as a 54 pint dehumidifier with an option for direct draining it has 3 cooling speeds and electronic controls with remote led display dual hoses draw fresh air in and push stale air out portable air conditioner dehumidifier and fan air conditioner 12 000 btuc ools areas up to 500 square feet 54 pint dehumidifier powerful 3 speed fan environmentally friendly r 410 a refrigerant direct drain option for continuous operation electronic controls with remote and led display auto on have the unit start or stop to meet your schedule dual hoses draw fresh air in push stale air out',
#  'frost king e o 1 1 4 inch x 42 inch polyurethane air conditioner weather seal with 15 inch x 24 inch filter frost king weatherproof your air conditioner easily with the thermwell products 1 1 4 inch x 42 inch polyurethane air conditioner weather seal with 15 inch x 24 inch filter the foam creates a tight seal around the air conditioner and the filter helps remove the dust and pollen cut to fit filter helps to remove dust and pollen seals tightly around air conditioner energy efficient open cell foam is compressible washable filter helps save money',
#  'air conditioner indoor cover small air keep rooms with wall air conditioners free from cold drafts and heat loss during the colder months with the help of an inner polyethylene foam liner air conditioner cover air conditioner cover provides a thick double layer of insulation to prevent cold air from entering the room air conditioner cover has an outer shell made up of a beige quilted fabric with an elastic edge to secure a snug fit air conditioner cover measures 12 14 inch h x 18 21 inch w measures 12 14 inch high by 18 21 inch wide washable fabric easy to use stops cold drafts and dirt this item does not qualify for the major appliance delivery haul away or installation services',
#  'air conditioner indoor cover large unbranded keep rooms with wall air conditioners free from cold drafts and heat loss during the colder months with the help of an inner polyethylene foam liner air conditioner cover air conditioner cover provides a thick double layer of insulation to prevent cold air from entering the room air conditioner cover has an outer shell made up of a beige quilted fabric with an elastic edge to secure a snug fit air conditioner cover measures 18 20 inch h x 26 28 inch w measures 18 20 inch high by 26 28 inch wide washable fabric easy to use stops cold drafts and dirt this item does not qualify for the major appliance delivery haul away or installation services',
#  'air conditioner indoor cover medium unbranded keep rooms with wall air conditioners free from cold drafts and heat loss during the colder months with the help of an inner polyethylene foam liner air conditioner cover air conditioner cover provides a thick double layer of insulation to prevent cold air from entering the room air conditioner cover has an outer shell made up of a beige quilted fabric with an elastic edge to secure a snug fit air conditioner cover measures 15 17 inch h x 22 25 inch w measures 15 17 inch high by 22 25 inch wide washable fabric easy to use stops cold drafts and dirt this item does not qualify for the major appliance delivery haul away or installation services',
#  'frost king e o 34 inch x 34 inch x 30 inch plastic square central air conditioner cover frost king the thermwell products 34 inch x 34 inch x 30 inch plastic square central air conditioner cover helps keep your central air conditioner unit protected from the elements air conditioners not included the cover features heavy duty winterized plastic construction to keep out dirt leaves and dust and the elastic straps ensure a snug fit cover for square central air conditioner units air conditioners not included seals out leaves dirt and dust protects against rust to help prolong the life of your central air conditioner air conditioners not included 6 mil reinforced winterized heavy gauge plastic elastic straps help ensure a snug fit 34 inch w x 34 inch l x 30 inch h']

# %%
import pickle
with open('BM25_model.pkl', 'wb') as f:
  pickle.dump(bm25, f)
